# %% [markdown]
# # Cleaning and Exploring PPP Loan Data: Python
#
# ## Project Description
# In this project, we use Python to import data from both Excel and .CSV files from the Small Business Administrations' (SBA) Paycheck Protection Program (PPP). In the first section we cover the process of cleaning the data and preparing it for analytical purposes. Next, during the exploration process we analyze the data utilizing the pandas, NumPy, matplotlib, and seaborn libraries to gain insights.

# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.set_option('display.max_column',55)

# %% [markdown]
# #### Read Data

# %%
df=pd.read_csv('Loan_data.csv')
df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  7488978407   02/12/2021            353              PPS
# 1  7500697109   04/14/2020            353              PPP
# 2  7582377001   04/07/2020            304              PPP
# 3  7729908900   05/07/2021            304              PPS
# 4  7742997010   04/08/2020            304              PPP
#
#                        BorrowerName  \
# 0  RELIANT HOSPITALITY SERVICES LLC
# 1               XPRESSPROMOTION INC
# 2              LAP MANAGEMENT, INC.
# 3                 GENESIS MANOR LLC
# 4   NORTHERN NECK SERVICE GROUP LLC
#
#                                      BorrowerAddress BorrowerCity  \
# 0                                    6303 Dunaway Ct      Mc Lean
# 1  5508 Port Royal Rd, http://xpresspromotion.com...  Springfield
# 2                                      2434 Gum Road   CHESAPEAKE
# 3                              108A Northwynd Circle    Lynchburg
# 4                                  215 CHESAPEAKE DR  WHITE STONE
#
#   BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0            VA  22101-2205     11/15/2022  Paid in Full    60
# 1            VA       22151     02/23/2021  Paid in Full    24
# 2            VA  23321-1510     08/17/2021  Paid in Full    24
# 3            VA       24502     12/18/2021  Paid in Full    60
# 4            VA  22578-2656     02/20/2021  Paid in Full    24
#
#    SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 0                    100                85000.0                85000.0
# 1                    100                85000.0                85000.0
# 2                    100                85000.0                85000.0
# 3                    100                85000.0                85000.0
# 4                    100                85000.0                85000.0
#
#    UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 0                0.0           NaN                      94031
# 1                0.0           NaN                     121536
# 2                0.0           NaN                     123548
# 3                0.0           NaN                     499141
# 4                0.0           NaN                      73496
#
#      ServicingLenderName        ServicingLenderAddress ServicingLenderCity  \
# 0          Northwest FCU                 200 Spring St             HERNDON
# 1         Customers Bank                  99 Bridge St        PHOENIXVILLE
# 2             Towne Bank             5716 High St West          PORTSMOUTH
# 3  Readycap Lending, LLC  200 Connell Drive Suite 4000    BERKELEY HEIGHTS
# 4        Chesapeake Bank                  97 N Main St          KILMARNOCK
#
#   ServicingLenderState ServicingLenderZip RuralUrbanIndicator  \
# 0                   VA         20170-5241                   U
# 1                   PA         19460-3411                   U
# 2                   VA         23703-4502                   U
# 3                   NJ              07922                   U
# 4                   VA         22482-8501                   R
#
#   HubzoneIndicator LMIIndicator             BusinessAgeDescription  \
# 0                N            N  Existing or more than 2 years old
# 1                N            N  Existing or more than 2 years old
# 2                N            N  Existing or more than 2 years old
# 3                N            N  Existing or more than 2 years old
# 4                Y            N  Existing or more than 2 years old
#
#    ProjectCity ProjectCountyName ProjectState  ProjectZip     CD  \
# 0      Mc Lean           FAIRFAX           VA  22101-2205  VA-10
# 1  Springfield           FAIRFAX           VA  22151-0001  VA-11
# 2   CHESAPEAKE   CHESAPEAKE CITY           VA  23321-1510  VA-03
# 3    Lynchburg    LYNCHBURG CITY           VA       24502  VA-05
# 4  WHITE STONE         LANCASTER           VA  22578-2656  VA-01
#
#    JobsReported  NAICSCode        Race          Ethnicity  UTILITIES_PROCEED  \
# 0           3.0   721110.0  Unanswered  Unknown/NotStated                NaN
# 1          10.0   453998.0  Unanswered  Unknown/NotStated                NaN
# 2           6.0   561210.0  Unanswered  Unknown/NotStated                NaN
# 3          28.0   623210.0  Unanswered  Unknown/NotStated                1.0
# 4           8.0   238990.0  Unanswered  Unknown/NotStated             1500.0
#
#    PAYROLL_PROCEED  MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  \
# 0          85000.0                        NaN           NaN
# 1          85000.0                        NaN           NaN
# 2          85000.0                        NaN           NaN
# 3          84998.0                        NaN           NaN
# 4          76200.0                     5500.0           NaN
#
#    REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 0                     NaN                  NaN                    NaN
# 1                     NaN                  NaN                    NaN
# 2                     NaN                  NaN                    NaN
# 3                     NaN                  NaN                    NaN
# 4                     NaN               1800.0                    NaN
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0  Limited  Liability Company(LLC)                        94031
# 1              Sole Proprietorship                       499141
# 2                      Corporation                       123548
# 3  Limited  Liability Company(LLC)                       499141
# 4  Limited  Liability Company(LLC)                        73496
#
#        OriginatingLender OriginatingLenderCity OriginatingLenderState  \
# 0          Northwest FCU               HERNDON                     VA
# 1  Readycap Lending, LLC      BERKELEY HEIGHTS                     NJ
# 2             Towne Bank            PORTSMOUTH                     VA
# 3  Readycap Lending, LLC      BERKELEY HEIGHTS                     NJ
# 4        Chesapeake Bank            KILMARNOCK                     VA
#
#        Gender      Veteran NonProfit  ForgivenessAmount ForgivenessDate
# 0  Unanswered   Unanswered       NaN           86454.44      10/26/2022
# 1  Male Owned  Non-Veteran       NaN           85570.55      01/07/2021
# 2  Unanswered   Unanswered       NaN           75514.58      12/17/2020
# 3  Unanswered   Unanswered       NaN           85407.53      11/10/2021
# 4  Unanswered   Unanswered       NaN           85637.50      01/11/2021

# %%
df.loc[df['LoanNumber'] == 7488978407]
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  7488978407   02/12/2021            353              PPS
#
#                        BorrowerName  BorrowerAddress BorrowerCity  \
# 0  RELIANT HOSPITALITY SERVICES LLC  6303 Dunaway Ct      Mc Lean
#
#   BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0            VA  22101-2205     11/15/2022  Paid in Full    60
#
#    SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 0                    100                85000.0                85000.0
#
#    UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 0                0.0           NaN                      94031
#
#   ServicingLenderName ServicingLenderAddress ServicingLenderCity  \
# 0       Northwest FCU          200 Spring St             HERNDON
#
#   ServicingLenderState ServicingLenderZip RuralUrbanIndicator  \
# 0                   VA         20170-5241                   U
#
#   HubzoneIndicator LMIIndicator             BusinessAgeDescription  \
# 0                N            N  Existing or more than 2 years old
#
#   ProjectCity ProjectCountyName ProjectState  ProjectZip     CD  JobsReported  \
# 0     Mc Lean           FAIRFAX           VA  22101-2205  VA-10           3.0
#
#    NAICSCode        Race          Ethnicity  UTILITIES_PROCEED  \
# 0   721110.0  Unanswered  Unknown/NotStated                NaN
#
#    PAYROLL_PROCEED  MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  \
# 0          85000.0                        NaN           NaN
#
#    REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 0                     NaN                  NaN                    NaN
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0  Limited  Liability Company(LLC)                        94031
#
#   OriginatingLender OriginatingLenderCity OriginatingLenderState      Gender  \
# 0     Northwest FCU               HERNDON                     VA  Unanswered
#
#       Veteran NonProfit  ForgivenessAmount ForgivenessDate
# 0  Unanswered       NaN           86454.44      10/26/2022

# %%
df.loc[df['BorrowerName'] == 'XPRESSPROMOTION INC']
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 1  7500697109   04/14/2020            353              PPP
#
#           BorrowerName                                    BorrowerAddress  \
# 1  XPRESSPROMOTION INC  5508 Port Royal Rd, http://xpresspromotion.com...
#
#   BorrowerCity BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 1  Springfield            VA       22151     02/23/2021  Paid in Full    24
#
#    SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 1                    100                85000.0                85000.0
#
#    UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 1                0.0           NaN                     121536
#
#   ServicingLenderName ServicingLenderAddress ServicingLenderCity  \
# 1      Customers Bank           99 Bridge St        PHOENIXVILLE
#
#   ServicingLenderState ServicingLenderZip RuralUrbanIndicator  \
# 1                   PA         19460-3411                   U
#
#   HubzoneIndicator LMIIndicator             BusinessAgeDescription  \
# 1                N            N  Existing or more than 2 years old
#
#    ProjectCity ProjectCountyName ProjectState  ProjectZip     CD  \
# 1  Springfield           FAIRFAX           VA  22151-0001  VA-11
#
#    JobsReported  NAICSCode        Race          Ethnicity  UTILITIES_PROCEED  \
# 1          10.0   453998.0  Unanswered  Unknown/NotStated                NaN
#
#    PAYROLL_PROCEED  MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  \
# 1          85000.0                        NaN           NaN
#
#    REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 1                     NaN                  NaN                    NaN
#
#           BusinessType  OriginatingLenderLocationID      OriginatingLender  \
# 1  Sole Proprietorship                       499141  Readycap Lending, LLC
#
#   OriginatingLenderCity OriginatingLenderState      Gender      Veteran  \
# 1      BERKELEY HEIGHTS                     NJ  Male Owned  Non-Veteran
#
#   NonProfit  ForgivenessAmount ForgivenessDate
# 1       NaN           85570.55      01/07/2021

# %%
df.duplicated(subset=['BorrowerName'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 599881    False
# 599882    False
# 599883    False
# 599884    False
# 599885    False
# Length: 599886, dtype: bool

# %%
print(df.duplicated(subset=['BorrowerName']=XPRESSPROMOTION INC)

# %%
# find where number of jobs is 0

df=print(df['JobsReported'].isin(['0']))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 599881    False
# 599882    False
# 599883    False
# 599884    False
# 599885    False
# Name: JobsReported, Length: 599886, dtype: bool

# %%
sns.countplot(df['JobsReported'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='JobsReported', ylabel='count'>

# %%
sns.countplot(df['BusinessAgeDescription'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BusinessAgeDescription', ylabel='count'>

# %%
sns.countplot(df['LoanStatus'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LoanStatus', ylabel='count'>

# %%
len(df[df["LoanStatus"]=="Paid in Full"])
len(df[df["LoanStatus"]=="Exemption 4"])
len(df[df["LoanStatus"]=="Charged Off Active"])

#len(df[df["LoanStatus"]=="Un-Disbursed"])
# Out:
# 0

# %% [markdown]
# #### More Concise .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599886 entries, 0 to 599885
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   599886 non-null  int64
#  1   DateApproved                 599886 non-null  object
#  2   SBAOfficeCode                599886 non-null  int64
#  3   ProcessingMethod             599886 non-null  object
#  4   BorrowerName                 599878 non-null  object
#  5   BorrowerAddress              599880 non-null  object
#  6   BorrowerCity                 599881 non-null  object
#  7   BorrowerState                599886 non-null  object
#  8   BorrowerZip                  599881 non-null  object
#  9   LoanStatusDate               575048 non-null  object
#  10  LoanStatus                   599886 non-null  object
#  11  Term                         599886 non-null  int64
#  12  SBAGuarantyPercentage        599886 non-null  int64
#  13  InitialApprovalAmount        599886 non-null  float64
#  14  CurrentApprovalAmount        599886 non-null  float64
#  15  UndisbursedAmount            599709 non-null  float64
#  16  FranchiseName                8235 non-null    object
#  17  ServicingLenderLocationID    599886 non-null  int64
#  18  ServicingLenderName          599886 non-null  object
#  19  ServicingLenderAddress       599886 non-null  object
#  20  ServicingLenderCity          599886 non-null  object
#  21  ServicingLenderState         599886 non-null  object
#  22  ServicingLenderZip           599886 non-null  object
#  23  RuralUrbanIndicator          599886 non-null  object
#  24  HubzoneIndicator             599886 non-null  object
#  25  LMIIndicator                 599886 non-null  object
#  26  BusinessAgeDescription       599886 non-null  object
#  27  ProjectCity                  599881 non-null  object
#  28  ProjectCountyName            599860 non-null  object
#  29  ProjectState                 599886 non-null  object
#  30  ProjectZip                   599881 non-null  object
#  31  CD                           599867 non-null  object
#  32  JobsReported                 599885 non-null  float64
#  33  NAICSCode                    594581 non-null  float64
#  34  Race                         599886 non-null  object
#  35  Ethnicity                    599886 non-null  object
#  36  UTILITIES_PROCEED            172009 non-null  float64
#  37  PAYROLL_PROCEED              599254 non-null  float64
#  38  MORTGAGE_INTEREST_PROCEED    14763 non-null   float64
#  39  RENT_PROCEED                 21602 non-null   float64
#  40  REFINANCE_EIDL_PROCEED       3568 non-null    float64
#  41  HEALTH_CARE_PROCEED          5894 non-null    float64
#  42  DEBT_INTEREST_PROCEED        3754 non-null    float64
#  43  BusinessType                 599822 non-null  object
#  44  OriginatingLenderLocationID  599886 non-null  int64
#  45  OriginatingLender            599886 non-null  object
#  46  OriginatingLenderCity        599886 non-null  object
#  47  OriginatingLenderState       599886 non-null  object
#  48  Gender                       599886 non-null  object
#  49  Veteran                      599886 non-null  object
#  50  NonProfit                    18062 non-null   object
#  51  ForgivenessAmount            566515 non-null  float64
#  52  ForgivenessDate              566515 non-null  object
# dtypes: float64(13), int64(6), object(34)
# memory usage: 242.6+ MB

# %% [markdown]
# #### Checking for NULLS

# %%
df.isnull().sum()
# Out:
# LoanNumber                          0
# DateApproved                        0
# SBAOfficeCode                       0
# ProcessingMethod                    0
# BorrowerName                        8
# BorrowerAddress                     6
# BorrowerCity                        5
# BorrowerState                       0
# BorrowerZip                         5
# LoanStatusDate                  24838
# LoanStatus                          0
# Term                                0
# SBAGuarantyPercentage               0
# InitialApprovalAmount               0
# CurrentApprovalAmount               0
# UndisbursedAmount                 177
# FranchiseName                  591651
# ServicingLenderLocationID           0
# ServicingLenderName                 0
# ServicingLenderAddress              0
# ServicingLenderCity                 0
# ServicingLenderState                0
# ServicingLenderZip                  0
# RuralUrbanIndicator                 0
# HubzoneIndicator                    0
# LMIIndicator                        0
# BusinessAgeDescription              0
# ProjectCity                         5
# ProjectCountyName                  26
# ProjectState                        0
# ProjectZip                          5
# CD                                 19
# JobsReported                        1
# NAICSCode                        5305
# Race                                0
# Ethnicity                           0
# UTILITIES_PROCEED              427877
# PAYROLL_PROCEED                   632
# MORTGAGE_INTEREST_PROCEED      585123
# RENT_PROCEED                   578284
# REFINANCE_EIDL_PROCEED         596318
# HEALTH_CARE_PROCEED            593992
# DEBT_INTEREST_PROCEED          596132
# BusinessType                       64
# OriginatingLenderLocationID         0
# OriginatingLender                   0
# OriginatingLenderCity               0
# OriginatingLenderState              0
# Gender                              0
# Veteran                             0
# NonProfit                      581824
# ForgivenessAmount               33371
# ForgivenessDate                 33371
# dtype: int64

# %% [markdown]
# #### Retrieve Relevant Records

# %%
df=df.loc[df['BorrowerName'].notnull()]
df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  7488978407   02/12/2021            353              PPS
# 1  7500697109   04/14/2020            353              PPP
# 2  7582377001   04/07/2020            304              PPP
# 3  7729908900   05/07/2021            304              PPS
# 4  7742997010   04/08/2020            304              PPP
#
#                        BorrowerName  \
# 0  RELIANT HOSPITALITY SERVICES LLC
# 1               XPRESSPROMOTION INC
# 2              LAP MANAGEMENT, INC.
# 3                 GENESIS MANOR LLC
# 4   NORTHERN NECK SERVICE GROUP LLC
#
#                                      BorrowerAddress BorrowerCity  \
# 0                                    6303 Dunaway Ct      Mc Lean
# 1  5508 Port Royal Rd, http://xpresspromotion.com...  Springfield
# 2                                      2434 Gum Road   CHESAPEAKE
# 3                              108A Northwynd Circle    Lynchburg
# 4                                  215 CHESAPEAKE DR  WHITE STONE
#
#   BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0            VA  22101-2205     11/15/2022  Paid in Full    60
# 1            VA       22151     02/23/2021  Paid in Full    24
# 2            VA  23321-1510     08/17/2021  Paid in Full    24
# 3            VA       24502     12/18/2021  Paid in Full    60
# 4            VA  22578-2656     02/20/2021  Paid in Full    24
#
#    SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 0                    100                85000.0                85000.0
# 1                    100                85000.0                85000.0
# 2                    100                85000.0                85000.0
# 3                    100                85000.0                85000.0
# 4                    100                85000.0                85000.0
#
#    UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 0                0.0           NaN                      94031
# 1                0.0           NaN                     121536
# 2                0.0           NaN                     123548
# 3                0.0           NaN                     499141
# 4                0.0           NaN                      73496
#
#      ServicingLenderName        ServicingLenderAddress ServicingLenderCity  \
# 0          Northwest FCU                 200 Spring St             HERNDON
# 1         Customers Bank                  99 Bridge St        PHOENIXVILLE
# 2             Towne Bank             5716 High St West          PORTSMOUTH
# 3  Readycap Lending, LLC  200 Connell Drive Suite 4000    BERKELEY HEIGHTS
# 4        Chesapeake Bank                  97 N Main St          KILMARNOCK
#
#   ServicingLenderState ServicingLenderZip RuralUrbanIndicator  \
# 0                   VA         20170-5241                   U
# 1                   PA         19460-3411                   U
# 2                   VA         23703-4502                   U
# 3                   NJ              07922                   U
# 4                   VA         22482-8501                   R
#
#   HubzoneIndicator LMIIndicator             BusinessAgeDescription  \
# 0                N            N  Existing or more than 2 years old
# 1                N            N  Existing or more than 2 years old
# 2                N            N  Existing or more than 2 years old
# 3                N            N  Existing or more than 2 years old
# 4                Y            N  Existing or more than 2 years old
#
#    ProjectCity ProjectCountyName ProjectState  ProjectZip     CD  \
# 0      Mc Lean           FAIRFAX           VA  22101-2205  VA-10
# 1  Springfield           FAIRFAX           VA  22151-0001  VA-11
# 2   CHESAPEAKE   CHESAPEAKE CITY           VA  23321-1510  VA-03
# 3    Lynchburg    LYNCHBURG CITY           VA       24502  VA-05
# 4  WHITE STONE         LANCASTER           VA  22578-2656  VA-01
#
#    JobsReported  NAICSCode        Race          Ethnicity  UTILITIES_PROCEED  \
# 0           3.0   721110.0  Unanswered  Unknown/NotStated                NaN
# 1          10.0   453998.0  Unanswered  Unknown/NotStated                NaN
# 2           6.0   561210.0  Unanswered  Unknown/NotStated                NaN
# 3          28.0   623210.0  Unanswered  Unknown/NotStated                1.0
# 4           8.0   238990.0  Unanswered  Unknown/NotStated             1500.0
#
#    PAYROLL_PROCEED  MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  \
# 0          85000.0                        NaN           NaN
# 1          85000.0                        NaN           NaN
# 2          85000.0                        NaN           NaN
# 3          84998.0                        NaN           NaN
# 4          76200.0                     5500.0           NaN
#
#    REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 0                     NaN                  NaN                    NaN
# 1                     NaN                  NaN                    NaN
# 2                     NaN                  NaN                    NaN
# 3                     NaN                  NaN                    NaN
# 4                     NaN               1800.0                    NaN
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0  Limited  Liability Company(LLC)                        94031
# 1              Sole Proprietorship                       499141
# 2                      Corporation                       123548
# 3  Limited  Liability Company(LLC)                       499141
# 4  Limited  Liability Company(LLC)                        73496
#
#        OriginatingLender OriginatingLenderCity OriginatingLenderState  \
# 0          Northwest FCU               HERNDON                     VA
# 1  Readycap Lending, LLC      BERKELEY HEIGHTS                     NJ
# 2             Towne Bank            PORTSMOUTH                     VA
# 3  Readycap Lending, LLC      BERKELEY HEIGHTS                     NJ
# 4        Chesapeake Bank            KILMARNOCK                     VA
#
#        Gender      Veteran NonProfit  ForgivenessAmount ForgivenessDate
# 0  Unanswered   Unanswered       NaN           86454.44      10/26/2022
# 1  Male Owned  Non-Veteran       NaN           85570.55      01/07/2021
# 2  Unanswered   Unanswered       NaN           75514.58      12/17/2020
# 3  Unanswered   Unanswered       NaN           85407.53      11/10/2021
# 4  Unanswered   Unanswered       NaN           85637.50      01/11/2021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 599878 entries, 0 to 599885
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   599878 non-null  int64
#  1   DateApproved                 599878 non-null  object
#  2   SBAOfficeCode                599878 non-null  int64
#  3   ProcessingMethod             599878 non-null  object
#  4   BorrowerName                 599878 non-null  object
#  5   BorrowerAddress              599872 non-null  object
#  6   BorrowerCity                 599873 non-null  object
#  7   BorrowerState                599878 non-null  object
#  8   BorrowerZip                  599873 non-null  object
#  9   LoanStatusDate               575041 non-null  object
#  10  LoanStatus                   599878 non-null  object
#  11  Term                         599878 non-null  int64
#  12  SBAGuarantyPercentage        599878 non-null  int64
#  13  InitialApprovalAmount        599878 non-null  float64
#  14  CurrentApprovalAmount        599878 non-null  float64
#  15  UndisbursedAmount            599701 non-null  float64
#  16  FranchiseName                8235 non-null    object
#  17  ServicingLenderLocationID    599878 non-null  int64
#  18  ServicingLenderName          599878 non-null  object
#  19  ServicingLenderAddress       599878 non-null  object
#  20  ServicingLenderCity          599878 non-null  object
#  21  ServicingLenderState         599878 non-null  object
#  22  ServicingLenderZip           599878 non-null  object
#  23  RuralUrbanIndicator          599878 non-null  object
#  24  HubzoneIndicator             599878 non-null  object
#  25  LMIIndicator                 599878 non-null  object
#  26  BusinessAgeDescription       599878 non-null  object
#  27  ProjectCity                  599873 non-null  object
#  28  ProjectCountyName            599852 non-null  object
#  29  ProjectState                 599878 non-null  object
#  30  ProjectZip                   599873 non-null  object
#  31  CD                           599859 non-null  object
#  32  JobsReported                 599877 non-null  float64
#  33  NAICSCode                    594574 non-null  float64
#  34  Race                         599878 non-null  object
#  35  Ethnicity                    599878 non-null  object
#  36  UTILITIES_PROCEED            172008 non-null  float64
#  37  PAYROLL_PROCEED              599246 non-null  float64
#  38  MORTGAGE_INTEREST_PROCEED    14763 non-null   float64
#  39  RENT_PROCEED                 21602 non-null   float64
#  40  REFINANCE_EIDL_PROCEED       3568 non-null    float64
#  41  HEALTH_CARE_PROCEED          5894 non-null    float64
#  42  DEBT_INTEREST_PROCEED        3754 non-null    float64
#  43  BusinessType                 599814 non-null  object
#  44  OriginatingLenderLocationID  599878 non-null  int64
#  45  OriginatingLender            599878 non-null  object
#  46  OriginatingLenderCity        599878 non-null  object
#  47  OriginatingLenderState       599878 non-null  object
#  48  Gender                       599878 non-null  object
#  49  Veteran                      599878 non-null  object
#  50  NonProfit                    18062 non-null   object
#  51  ForgivenessAmount            566508 non-null  float64
#  52  ForgivenessDate              566508 non-null  object
# dtypes: float64(13), int64(6), object(34)
# memory usage: 247.1+ MB

# %% [markdown]
# #### Insert DatetimeIndex Columns

# %%
df['year_approved']=pd.DatetimeIndex(df['DateApproved']).year
df['month_approved']=pd.DatetimeIndex(df['DateApproved']).month

df['year_forgiven']=pd.DatetimeIndex(df['ForgivenessDate']).year
df['month_forgiven']=pd.DatetimeIndex(df['ForgivenessDate']).month

# %%
df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  7488978407   02/12/2021            353              PPS
# 1  7500697109   04/14/2020            353              PPP
# 2  7582377001   04/07/2020            304              PPP
# 3  7729908900   05/07/2021            304              PPS
# 4  7742997010   04/08/2020            304              PPP
#
#                        BorrowerName  \
# 0  RELIANT HOSPITALITY SERVICES LLC
# 1               XPRESSPROMOTION INC
# 2              LAP MANAGEMENT, INC.
# 3                 GENESIS MANOR LLC
# 4   NORTHERN NECK SERVICE GROUP LLC
#
#                                      BorrowerAddress BorrowerCity  \
# 0                                    6303 Dunaway Ct      Mc Lean
# 1  5508 Port Royal Rd, http://xpresspromotion.com...  Springfield
# 2                                      2434 Gum Road   CHESAPEAKE
# 3                              108A Northwynd Circle    Lynchburg
# 4                                  215 CHESAPEAKE DR  WHITE STONE
#
#   BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0            VA  22101-2205     11/15/2022  Paid in Full    60
# 1            VA       22151     02/23/2021  Paid in Full    24
# 2            VA  23321-1510     08/17/2021  Paid in Full    24
# 3            VA       24502     12/18/2021  Paid in Full    60
# 4            VA  22578-2656     02/20/2021  Paid in Full    24
#
#    SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 0                    100                85000.0                85000.0
# 1                    100                85000.0                85000.0
# 2                    100                85000.0                85000.0
# 3                    100                85000.0                85000.0
# 4                    100                85000.0                85000.0
#
#    UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 0                0.0           NaN                      94031
# 1                0.0           NaN                     121536
# 2                0.0           NaN                     123548
# 3                0.0           NaN                     499141
# 4                0.0           NaN                      73496
#
#      ServicingLenderName        ServicingLenderAddress ServicingLenderCity  \
# 0          Northwest FCU                 200 Spring St             HERNDON
# 1         Customers Bank                  99 Bridge St        PHOENIXVILLE
# 2             Towne Bank             5716 High St West          PORTSMOUTH
# 3  Readycap Lending, LLC  200 Connell Drive Suite 4000    BERKELEY HEIGHTS
# 4        Chesapeake Bank                  97 N Main St          KILMARNOCK
#
#   ServicingLenderState ServicingLenderZip RuralUrbanIndicator  \
# 0                   VA         20170-5241                   U
# 1                   PA         19460-3411                   U
# 2                   VA         23703-4502                   U
# 3                   NJ              07922                   U
# 4                   VA         22482-8501                   R
#
#   HubzoneIndicator LMIIndicator             BusinessAgeDescription  ...  \
# 0                N            N  Existing or more than 2 years old  ...
# 1                N            N  Existing or more than 2 years old  ...
# 2                N            N  Existing or more than 2 years old  ...
# 3                N            N  Existing or more than 2 years old  ...
# 4                Y            N  Existing or more than 2 years old  ...
#
#    ProjectZip     CD JobsReported NAICSCode        Race          Ethnicity  \
# 0  22101-2205  VA-10          3.0  721110.0  Unanswered  Unknown/NotStated
# 1  22151-0001  VA-11         10.0  453998.0  Unanswered  Unknown/NotStated
# 2  23321-1510  VA-03          6.0  561210.0  Unanswered  Unknown/NotStated
# 3       24502  VA-05         28.0  623210.0  Unanswered  Unknown/NotStated
# 4  22578-2656  VA-01          8.0  238990.0  Unanswered  Unknown/NotStated
#
#    UTILITIES_PROCEED PAYROLL_PROCEED MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  \
# 0                NaN         85000.0                       NaN           NaN
# 1                NaN         85000.0                       NaN           NaN
# 2                NaN         85000.0                       NaN           NaN
# 3                1.0         84998.0                       NaN           NaN
# 4             1500.0         76200.0                    5500.0           NaN
#
#    REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 0                     NaN                  NaN                    NaN
# 1                     NaN                  NaN                    NaN
# 2                     NaN                  NaN                    NaN
# 3                     NaN                  NaN                    NaN
# 4                     NaN               1800.0                    NaN
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0  Limited  Liability Company(LLC)                        94031
# 1              Sole Proprietorship                       499141
# 2                      Corporation                       123548
# 3  Limited  Liability Company(LLC)                       499141
# 4  Limited  Liability Company(LLC)                        73496
#
#        OriginatingLender OriginatingLenderCity  OriginatingLenderState  \
# 0          Northwest FCU               HERNDON                      VA
# 1  Readycap Lending, LLC      BERKELEY HEIGHTS                      NJ
# 2             Towne Bank            PORTSMOUTH                      VA
# 3  Readycap Lending, LLC      BERKELEY HEIGHTS                      NJ
# 4        Chesapeake Bank            KILMARNOCK                      VA
#
#        Gender      Veteran NonProfit ForgivenessAmount ForgivenessDate  \
# 0  Unanswered   Unanswered       NaN          86454.44      10/26/2022
# 1  Male Owned  Non-Veteran       NaN          85570.55      01/07/2021
# 2  Unanswered   Unanswered       NaN          75514.58      12/17/2020
# 3  Unanswered   Unanswered       NaN          85407.53      11/10/2021
# 4  Unanswered   Unanswered       NaN          85637.50      01/11/2021
#
#   year_approved  month_approved year_forgiven  month_forgiven
# 0          2021               2        2022.0            10.0
# 1          2020               4        2021.0             1.0
# 2          2020               4        2020.0            12.0
# 3          2021               5        2021.0            11.0
# 4          2020               4        2021.0             1.0
#
# [5 rows x 57 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 599878 entries, 0 to 599885
# Data columns (total 57 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   599878 non-null  int64
#  1   DateApproved                 599878 non-null  object
#  2   SBAOfficeCode                599878 non-null  int64
#  3   ProcessingMethod             599878 non-null  object
#  4   BorrowerName                 599878 non-null  object
#  5   BorrowerAddress              599872 non-null  object
#  6   BorrowerCity                 599873 non-null  object
#  7   BorrowerState                599878 non-null  object
#  8   BorrowerZip                  599873 non-null  object
#  9   LoanStatusDate               575041 non-null  object
#  10  LoanStatus                   599878 non-null  object
#  11  Term                         599878 non-null  int64
#  12  SBAGuarantyPercentage        599878 non-null  int64
#  13  InitialApprovalAmount        599878 non-null  float64
#  14  CurrentApprovalAmount        599878 non-null  float64
#  15  UndisbursedAmount            599701 non-null  float64
#  16  FranchiseName                8235 non-null    object
#  17  ServicingLenderLocationID    599878 non-null  int64
#  18  ServicingLenderName          599878 non-null  object
#  19  ServicingLenderAddress       599878 non-null  object
#  20  ServicingLenderCity          599878 non-null  object
#  21  ServicingLenderState         599878 non-null  object
#  22  ServicingLenderZip           599878 non-null  object
#  23  RuralUrbanIndicator          599878 non-null  object
#  24  HubzoneIndicator             599878 non-null  object
#  25  LMIIndicator                 599878 non-null  object
#  26  BusinessAgeDescription       599878 non-null  object
#  27  ProjectCity                  599873 non-null  object
#  28  ProjectCountyName            599852 non-null  object
#  29  ProjectState                 599878 non-null  object
#  30  ProjectZip                   599873 non-null  object
#  31  CD                           599859 non-null  object
#  32  JobsReported                 599877 non-null  float64
#  33  NAICSCode                    594574 non-null  float64
#  34  Race                         599878 non-null  object
#  35  Ethnicity                    599878 non-null  object
#  36  UTILITIES_PROCEED            172008 non-null  float64
#  37  PAYROLL_PROCEED              599246 non-null  float64
#  38  MORTGAGE_INTEREST_PROCEED    14763 non-null   float64
#  39  RENT_PROCEED                 21602 non-null   float64
#  40  REFINANCE_EIDL_PROCEED       3568 non-null    float64
#  41  HEALTH_CARE_PROCEED          5894 non-null    float64
#  42  DEBT_INTEREST_PROCEED        3754 non-null    float64
#  43  BusinessType                 599814 non-null  object
#  44  OriginatingLenderLocationID  599878 non-null  int64
#  45  OriginatingLender            599878 non-null  object
#  46  OriginatingLenderCity        599878 non-null  object
#  47  OriginatingLenderState       599878 non-null  object
#  48  Gender                       599878 non-null  object
#  49  Veteran                      599878 non-null  object
#  50  NonProfit                    18062 non-null   object
#  51  ForgivenessAmount            566508 non-null  float64
#  52  ForgivenessDate              566508 non-null  object
#  53  year_approved                599878 non-null  int64
#  54  month_approved               599878 non-null  int64
#  55  year_forgiven                566508 non-null  float64
#  56  month_forgiven               566508 non-null  float64
# dtypes: float64(15), int64(8), object(34)
# memory usage: 265.4+ MB

# %% [markdown]
# #### Build FirstRound Dataframe

# %%
FirstRound=df.loc[df['ProcessingMethod']=='PPP']
FirstRound.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 1  7500697109   04/14/2020            353              PPP
# 2  7582377001   04/07/2020            304              PPP
# 4  7742997010   04/08/2020            304              PPP
# 5  7758397208   04/28/2020            304              PPP
# 6  7803247307   04/30/2020            304              PPP
#
#                       BorrowerName  \
# 1              XPRESSPROMOTION INC
# 2             LAP MANAGEMENT, INC.
# 4  NORTHERN NECK SERVICE GROUP LLC
# 5             COOPER VINEYARDS LLC
# 6                          APEX MD
#
#                                      BorrowerAddress BorrowerCity  \
# 1  5508 Port Royal Rd, http://xpresspromotion.com...  Springfield
# 2                                      2434 Gum Road   CHESAPEAKE
# 4                                  215 CHESAPEAKE DR  WHITE STONE
# 5                            13372 Shannon Hill Road       Louisa
# 6                               5310 Twin Hickory Rd   GLEN ALLEN
#
#   BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 1            VA       22151     02/23/2021  Paid in Full    24
# 2            VA  23321-1510     08/17/2021  Paid in Full    24
# 4            VA  22578-2656     02/20/2021  Paid in Full    24
# 5            VA       23093     04/10/2021  Paid in Full    24
# 6            VA       23059     03/19/2021  Paid in Full    24
#
#    SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 1                    100                85000.0                85000.0
# 2                    100                85000.0                85000.0
# 4                    100                85000.0                85000.0
# 5                    100                85000.0                85000.0
# 6                    100                85000.0                85000.0
#
#    UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 1                0.0           NaN                     121536
# 2                0.0           NaN                     123548
# 4                0.0           NaN                      73496
# 5                0.0           NaN                     434059
# 6                0.0           NaN                     124336
#
#                      ServicingLenderName        ServicingLenderAddress  \
# 1                         Customers Bank                  99 Bridge St
# 2                             Towne Bank             5716 High St West
# 4                        Chesapeake Bank                  97 N Main St
# 5                            Primis Bank               307 Church Lane
# 6  Blue Ridge Bank, National Association  1 E Market St Imperial Plaza
#
#   ServicingLenderCity ServicingLenderState ServicingLenderZip  \
# 1        PHOENIXVILLE                   PA         19460-3411
# 2          PORTSMOUTH                   VA         23703-4502
# 4          KILMARNOCK                   VA         22482-8501
# 5        TAPPAHANNOCK                   VA              22560
# 6        MARTINSVILLE                   VA              24112
#
#   RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# 1                   U                N            N
# 2                   U                N            N
# 4                   R                Y            N
# 5                   R                N            N
# 6                   U                N            N
#
#               BusinessAgeDescription  ...  ProjectZip     CD JobsReported  \
# 1  Existing or more than 2 years old  ...  22151-0001  VA-11         10.0
# 2  Existing or more than 2 years old  ...  23321-1510  VA-03          6.0
# 4  Existing or more than 2 years old  ...  22578-2656  VA-01          8.0
# 5  Existing or more than 2 years old  ...  23093-0001  VA-07         22.0
# 6  Existing or more than 2 years old  ...  23059-1000  VA-07          7.0
#
#   NAICSCode        Race          Ethnicity  UTILITIES_PROCEED PAYROLL_PROCEED  \
# 1  453998.0  Unanswered  Unknown/NotStated                NaN         85000.0
# 2  561210.0  Unanswered  Unknown/NotStated                NaN         85000.0
# 4  238990.0  Unanswered  Unknown/NotStated             1500.0         76200.0
# 5  111332.0  Unanswered  Unknown/NotStated                NaN         85000.0
# 6  621111.0  Unanswered  Unknown/NotStated             2000.0         70000.0
#
#   MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  REFINANCE_EIDL_PROCEED  \
# 1                       NaN           NaN                     NaN
# 2                       NaN           NaN                     NaN
# 4                    5500.0           NaN                     NaN
# 5                       NaN           NaN                     NaN
# 6                       NaN       10000.0                     NaN
#
#    HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 1                  NaN                    NaN
# 2                  NaN                    NaN
# 4               1800.0                    NaN
# 5                  NaN                    NaN
# 6               3000.0                    NaN
#
#                       BusinessType  OriginatingLenderLocationID  \
# 1              Sole Proprietorship                       499141
# 2                      Corporation                       123548
# 4  Limited  Liability Company(LLC)                        73496
# 5  Limited  Liability Company(LLC)                       434059
# 6  Limited  Liability Company(LLC)                       124336
#
#                        OriginatingLender OriginatingLenderCity  \
# 1                  Readycap Lending, LLC      BERKELEY HEIGHTS
# 2                             Towne Bank            PORTSMOUTH
# 4                        Chesapeake Bank            KILMARNOCK
# 5                            Primis Bank          TAPPAHANNOCK
# 6  Blue Ridge Bank, National Association          MARTINSVILLE
#
#    OriginatingLenderState      Gender      Veteran NonProfit  \
# 1                      NJ  Male Owned  Non-Veteran       NaN
# 2                      VA  Unanswered   Unanswered       NaN
# 4                      VA  Unanswered   Unanswered       NaN
# 5                      VA  Unanswered   Unanswered       NaN
# 6                      VA  Unanswered   Unanswered       NaN
#
#   ForgivenessAmount ForgivenessDate year_approved  month_approved  \
# 1          85570.55      01/07/2021          2020               4
# 2          75514.58      12/17/2020          2020               4
# 4          85637.50      01/11/2021          2020               4
# 5          85752.19      03/18/2021          2020               4
# 6          78452.83      12/02/2020          2020               4
#
#   year_forgiven  month_forgiven
# 1        2021.0             1.0
# 2        2020.0            12.0
# 4        2021.0             1.0
# 5        2021.0             3.0
# 6        2020.0            12.0
#
# [5 rows x 57 columns]

# %% [markdown]
# #### Build SecondRound Dataframe

# %%
SecondRound= df.loc[df['ProcessingMethod']=='PPS']
SecondRound.head()
# Out:
#     LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0   7488978407   02/12/2021            353              PPS
# 3   7729908900   05/07/2021            304              PPS
# 7   7890008407   02/12/2021            353              PPS
# 19  4341258405   02/06/2021            353              PPS
# 21  5947758510   03/02/2021            304              PPS
#
#                                   BorrowerName              BorrowerAddress  \
# 0             RELIANT HOSPITALITY SERVICES LLC              6303 Dunaway Ct
# 3                            GENESIS MANOR LLC        108A Northwynd Circle
# 7   1ST AMERICAN HOME HEALTH CARE SERVICESINC.  6216 Old Franconia Rd Ste A
# 19                    NOVA FOOT AND ANKLE PLLC                 112 Elden St
# 21                            UTOPIA SALON LLC       150 Rivendell Ct Ste 1
#
#    BorrowerCity BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0       Mc Lean            VA  22101-2205     11/15/2022  Paid in Full    60
# 3     Lynchburg            VA       24502     12/18/2021  Paid in Full    60
# 7    Alexandria            VA  22310-3401     05/19/2022  Paid in Full    60
# 19      Herndon            VA  20170-4874     02/19/2022  Paid in Full    60
# 21   Winchester            VA  22603-8644     09/14/2021  Paid in Full    60
#
#     SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 0                     100               85000.00               85000.00
# 3                     100               85000.00               85000.00
# 7                     100               85000.00               85000.00
# 19                    100               84998.33               84998.33
# 21                    100               84990.00               84990.00
#
#     UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 0                 0.0           NaN                      94031
# 3                 0.0           NaN                     499141
# 7                 0.0           NaN                     499141
# 19                0.0           NaN                     378264
# 21                0.0           NaN                      73259
#
#       ServicingLenderName        ServicingLenderAddress ServicingLenderCity  \
# 0           Northwest FCU                 200 Spring St             HERNDON
# 3   Readycap Lending, LLC  200 Connell Drive Suite 4000    BERKELEY HEIGHTS
# 7   Readycap Lending, LLC  200 Connell Drive Suite 4000    BERKELEY HEIGHTS
# 19        MainStreet Bank            10089 Fairfax Blvd             FAIRFAX
# 21            United Bank            11185 Fairfax Blvd             FAIRFAX
#
#    ServicingLenderState ServicingLenderZip RuralUrbanIndicator  \
# 0                    VA         20170-5241                   U
# 3                    NJ              07922                   U
# 7                    NJ              07922                   U
# 19                   VA         22030-1742                   U
# 21                   VA         22030-5049                   R
#
#    HubzoneIndicator LMIIndicator             BusinessAgeDescription  ...  \
# 0                 N            N  Existing or more than 2 years old  ...
# 3                 N            N  Existing or more than 2 years old  ...
# 7                 N            N  Existing or more than 2 years old  ...
# 19                N            N  Existing or more than 2 years old  ...
# 21                Y            Y  Existing or more than 2 years old  ...
#
#     ProjectZip     CD JobsReported NAICSCode        Race  \
# 0   22101-2205  VA-10          3.0  721110.0  Unanswered
# 3        24502  VA-05         28.0  623210.0  Unanswered
# 7   22310-3401  VA-08          7.0  621610.0  Unanswered
# 19  20170-4874  VA-11          9.0  621391.0  Unanswered
# 21  22603-8644  VA-10         16.0  812112.0  Unanswered
#
#                  Ethnicity  UTILITIES_PROCEED PAYROLL_PROCEED  \
# 0        Unknown/NotStated                NaN        85000.00
# 3        Unknown/NotStated                1.0        84998.00
# 7   Not Hispanic or Latino                1.0        84994.00
# 19       Unknown/NotStated                1.0        84994.33
# 21       Unknown/NotStated                1.0        84988.00
#
#    MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  REFINANCE_EIDL_PROCEED  \
# 0                        NaN           NaN                     NaN
# 3                        NaN           NaN                     NaN
# 7                        NaN           NaN                     NaN
# 19                       NaN           NaN                     NaN
# 21                       NaN           NaN                     NaN
#
#     HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 0                   NaN                    NaN
# 3                   NaN                    NaN
# 7                   NaN                    NaN
# 19                  NaN                    NaN
# 21                  NaN                    NaN
#
#                        BusinessType  OriginatingLenderLocationID  \
# 0   Limited  Liability Company(LLC)                        94031
# 3   Limited  Liability Company(LLC)                       499141
# 7               Sole Proprietorship                       499141
# 19         Subchapter S Corporation                       378264
# 21  Limited  Liability Company(LLC)                        73259
#
#         OriginatingLender OriginatingLenderCity  OriginatingLenderState  \
# 0           Northwest FCU               HERNDON                      VA
# 3   Readycap Lending, LLC      BERKELEY HEIGHTS                      NJ
# 7   Readycap Lending, LLC      BERKELEY HEIGHTS                      NJ
# 19        MainStreet Bank               FAIRFAX                      VA
# 21            United Bank               FAIRFAX                      VA
#
#         Gender      Veteran NonProfit ForgivenessAmount ForgivenessDate  \
# 0   Unanswered   Unanswered       NaN          86454.44      10/26/2022
# 3   Unanswered   Unanswered       NaN          85407.53      11/10/2021
# 7   Male Owned  Non-Veteran       NaN          85973.42      04/13/2022
# 19  Unanswered   Unanswered       NaN          85799.41      01/28/2022
# 21  Unanswered   Unanswered       NaN          85332.32      08/04/2021
#
#    year_approved  month_approved year_forgiven  month_forgiven
# 0           2021               2        2022.0            10.0
# 3           2021               5        2021.0            11.0
# 7           2021               2        2022.0             4.0
# 19          2021               2        2022.0             1.0
# 21          2021               3        2021.0             8.0
#
# [5 rows x 57 columns]

# %% [markdown]
# # CATEGORICAL VARIABLES

# %% [markdown]
# ## Univariate

# %% [markdown]
# #### Count ProcessingMethod Column

# %%
sns.countplot(df['ProcessingMethod'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ProcessingMethod', ylabel='count'>

# %% [markdown]
# #### Count LoanStatus Column

# %%
#Lets look at the LoanStatus of the borrowers. We can see that most borrowers PPP loans have been forgiven in full.
sns.countplot(df['LoanStatus'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LoanStatus', ylabel='count'>

# %% [markdown]
# #### Count BorrowerState Column

# %%
plt.figure(figsize=(15,6))  #this creates an 8 inch wide, 4 inch high
ax=sns.countplot(x="BorrowerState", data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

#plt.tight_layout()
plt.show()

# %% [markdown]
# #### Count Ethnicity Column

# %%
#Lets look at the Ethnicity of the borrowers. We can see that most borrowers ethnicity is unknown. 
sns.countplot(df['Ethnicity'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %% [markdown]
# #### Count BusinessType Column

# %%
#When we look at "BusinessType" we need to make the graph bigger by levraging plt.figure() and plot the state on the 
# x-axis 

plt.figure(figsize=(15,6))  #8 inch wide by 4 inch high chart
ax=sns.countplot(x="BusinessType", data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

#plt.tight_layout()
plt.show()

# %% [markdown]
# # CATEGORICAL VARIABLES

# %% [markdown]
# ## Bivariate

# %% [markdown]
# #### Plotting Ethnicity vs. Loan Status

# %%
#Plotting Ethnicity Against Loan Status
sns.countplot(x='Ethnicity',hue='LoanStatus', data=df)
# Out:
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %% [markdown]
# #### Crosstab - BorrowerState vs Ethnicity

# %%
pd.crosstab(df['BorrowerState'], df['Ethnicity'])
# Out:
# Ethnicity      Hispanic or Latino  Not Hispanic or Latino  Unknown/NotStated
# BorrowerState
# VA                           2765                   39566             139594
# VI                            163                     891               2059
# VT                             75                    5013              14342
# WA                           3672                   40343             127464
# WI                           1765                   47826             120872
# WV                            158                    9518              20276
# WY                            404                    6106              17006

# %% [markdown]
# #### Crosstab - Year_Approved vs BorrowerState

# %%
pd.crosstab(df['year_approved'], df['BorrowerState'])
# Out:
# BorrowerState     VA    VI     VT     WA     WI     WV     WY
# year_approved
# 2020           86737  1864  10785  90871  76659  15687  12161
# 2021           95188  1249   8645  80608  93804  14265  11355

# %% [markdown]
# #### Crosstab - Ethnicity vs LoanStatus

# %%
pd.crosstab(df['Ethnicity'], df['LoanStatus'])
# Out:
# LoanStatus              Active Un-Disbursed  Charged Off  Exemption 4  \
# Ethnicity
# Hispanic or Latino                        0          111          450
# Not Hispanic or Latino                    4          964         6125
# Unknown/NotStated                         3         6452        18262
#
# LoanStatus              Paid in Full
# Ethnicity
# Hispanic or Latino              8441
# Not Hispanic or Latino        142170
# Unknown/NotStated             416896

# %% [markdown]
# # NUMERICAL VARIABLES
# ## Discrete

# %% [markdown]
# #### Descriptive Summary

# %%
df['CurrentApprovalAmount'].describe().astype(int)
# Out:
# count    599878
# mean      27250
# std       28316
# min           1
# 25%        8600
# 50%       19377
# 75%       33330
# max      149999
# Name: CurrentApprovalAmount, dtype: int64

# %% [markdown]
# #### Outliers - CurrentApprovalAmount

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x=df['CurrentApprovalAmount']/10)
# Out:
# <AxesSubplot:xlabel='CurrentApprovalAmount'>

# %% [markdown]
# #### Outliers - LoanStatus vs. CurrentApprovalAmount

# %%
plt.figure(figsize=(15,6))
sns.boxplot(x='LoanStatus', y='CurrentApprovalAmount', data=df)
# Out:
# <AxesSubplot:xlabel='LoanStatus', ylabel='CurrentApprovalAmount'>

# %% [markdown]
# #### Distribution Analysis

# %% [markdown]
# The column is positively skewed.

# %%
plt.figure(figsize=(15,6))
sns.distplot(df['CurrentApprovalAmount'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CurrentApprovalAmount', ylabel='Density'>

# %% [markdown]
# #### Skew

# %% [markdown]
# A skewness value of 5.759 confirms that the data is highly positively skewed

# %%
df['CurrentApprovalAmount'].skew()
# Out:
# 1.958450649605944

# %% [markdown]
# #### Kurtosis

# %% [markdown]
# A kurtosis value > 3 indicates a distribution that is more peaked than a normal distribution.

# %%
df['CurrentApprovalAmount'].kurt()
# Out:
# 3.8081643535926575

# %% [markdown]
# #### Correlation

# %% [markdown]
# The correlation matrix shows a strong correlation between "ForgivenessAmount" and the "InitialApprovalAmount", "CurrentApprovalAmount "and "PAYROLL_PROCEED" columns all showing a correlation coefficient of (.99).

# %%
matrix=df.corr()
f,ax=plt.subplots(figsize=(18,10))
sns.heatmap(matrix, annot=True)
# Out:
# <AxesSubplot:>
